# %%
# !pip install --upgrade tensorflow
# !pip install tf-quant-finance
# !pip install tqdm

# %%
#@title Imports { display-mode: "form" }

import matplotlib.pyplot as plt
import numpy as np
import time

import tensorflow as tf

import QuantLib as ql

 # tff for Tensorflow Finance
import tf_quant_finance as tff

from IPython.core.pylabtools import figsize
figsize(21, 14) # better graph size for Colab  

from tqdm.notebook import tqdm, trange

# %%
#@title Set up parameters

dtype = np.float64 #@param
num_samples = 10#200000 #@param

num_timesteps = 2#100 #@param

expiries = [1.0] # This can be a rank 1 Tensor
dt = 1. / num_timesteps
rate = tf.constant(0.03, dtype=dtype)
sigma = tf.constant(0.1, dtype=dtype)
spot = tf.constant(700, dtype=dtype)

def set_up_pricer(expiries, watch_params=False):
    """Set up European option pricing function under Black-Scholes model.
    
    Args:
        expiries: List of expiries at which to to sample the trajectories.
        watch_params: A Python bool. When `True`, gradients of the price function wrt the inputs
          are computed more efficiently. 
    Returns:
     A callable that accepts a rank 1 tensor of strikes, and scalar values for 
     the spots and  volatility values. The callable outputs prices of
     the European call options on the grid `expiries x strikes`.
    """
    def price_eu_options(strikes, spot, sigma):
        # Define drift and volatility functions. 
        def drift_fn(t, x):
          del t, x
          return rate - 0.5 * sigma**2
        def vol_fn(t, x):
          del t, x
          return tf.reshape(sigma, [1, 1])
        # Use GenericItoProcess class to set up the Ito process
        process = tff.models.GenericItoProcess(
            dim=1,
            drift_fn=drift_fn,
            volatility_fn=vol_fn,
            dtype=dtype)
        log_spot = tf.math.log(tf.reduce_mean(spot))
        if watch_params:
            watch_params_list = [sigma]
        else:
            watch_params_list = None
        paths = process.sample_paths(
            expiries, num_samples=num_samples,
            initial_state=log_spot, 
            watch_params=watch_params_list,
            # Select a random number generator
            random_type=tff.math.random.RandomType.PSEUDO_ANTITHETIC,
            time_step=dt)
        prices = (tf.exp(-tf.expand_dims(rate * expiries, axis=-1))
                  * tf.reduce_mean(tf.nn.relu(tf.math.exp(paths) - strikes), 0))
        return prices
    return price_eu_options

price_eu_options = tf.function(set_up_pricer(expiries))

# %%
for i in trange(1, 100000):
    strikes = tf.constant(np.random.rand(i) * (0.5*spot) + spot, dtype )
    price_eu_options(strikes, spot, sigma)
# Out:
#   0%|          | 0/99999 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 5 calls to <function set_up_pricer.<locals>.price_eu_options at 0x000001D4052FF558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function set_up_pricer.<locals>.price_eu_options at 0x000001D4052FF558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_64928/1841580350.py in <module>
#       1 for i in trange(1, 100000):
#       2     strikes = tf.constant(np.random.rand(i) * (0.5*spot) + spot, dtype )
# ----> 3     price_eu_options(strikes, spot, sigma)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3127     with self._lock:
#    3128       (graph_function,
# -> 3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3400             arg_names=arg_names,
#    3401             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3402             capture_by_value=self._capture_by_value),
#    3403         self._function_attributes,
#    3404         function_spec=self.function_spec,
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1123                     recursive=True,
#    1124                     optional_features=autograph_options,
# -> 1125                     user_requested=True,
#    1126                 ))
#    1127           except Exception as e:  # pylint:disable=broad-except
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443     try:
#     444       if kwargs is not None:
# --> 445         result = converted_f(*effective_args, **kwargs)
#     446       else:
#     447         result = converted_f(*effective_args)
#
# ~\AppData\Local\Temp\__autograph_generated_filem3xtxdip.py in tf__price_eu_options(strikes, spot, sigma)
#      59                 watch_params_list = ag__.Undefined('watch_params_list')
#      60                 ag__.if_stmt(ag__.ld(watch_params), if_body, else_body, get_state, set_state, ('watch_params_list',), 1)
# ---> 61                 paths = ag__.converted_call(ag__.ld(process).sample_paths, (ag__.ld(expiries),), dict(num_samples=ag__.ld(num_samples), initial_state=ag__.ld(log_spot), watch_params=ag__.ld(watch_params_list), random_type=ag__.ld(tff).math.random.RandomType.PSEUDO_ANTITHETIC, time_step=ag__.ld(dt)), fscope)
#      62                 prices = (ag__.converted_call(ag__.ld(tf).exp, ((- ag__.converted_call(ag__.ld(tf).expand_dims, ((ag__.ld(rate) * ag__.ld(expiries)),), dict(axis=(- 1)), fscope)),), None, fscope) * ag__.converted_call(ag__.ld(tf).reduce_mean, (ag__.converted_call(ag__.ld(tf).nn.relu, ((ag__.converted_call(ag__.ld(tf).math.exp, (ag__.ld(paths),), None, fscope) - ag__.ld(strikes)),), None, fscope), 0), None, fscope))
#      63                 try:
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443     try:
#     444       if kwargs is not None:
# --> 445         result = converted_f(*effective_args, **kwargs)
#     446       else:
#     447         result = converted_f(*effective_args)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tf_quant_finance\models\generic_ito_process.py in tf__sample_paths(self, times, num_samples, initial_state, random_type, seed, swap_memory, name, time_step, num_time_steps, skip, precompute_normal_draws, times_grid, normal_draws, watch_params, validate_args)
#      13                     try:
#      14                         do_return = True
# ---> 15                         retval_ = ag__.converted_call(ag__.ld(euler_sampling).sample, (), dict(dim=ag__.ld(self)._dim, drift_fn=ag__.ld(self)._drift_fn, volatility_fn=ag__.ld(self)._volatility_fn, times=ag__.ld(times), num_samples=ag__.ld(num_samples), initial_state=ag__.ld(initial_state), random_type=ag__.ld(random_type), time_step=ag__.ld(time_step), num_time_steps=ag__.ld(num_time_steps), seed=ag__.ld(seed), swap_memory=ag__.ld(swap_memory), skip=ag__.ld(skip), precompute_normal_draws=ag__.ld(precompute_normal_draws), times_grid=ag__.ld(times_grid), normal_draws=ag__.ld(normal_draws), watch_params=ag__.ld(watch_params), dtype=ag__.ld(self)._dtype, name=ag__.ld(name)), fscope)
#      16                     except:
#      17                         do_return = False
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443     try:
#     444       if kwargs is not None:
# --> 445         result = converted_f(*effective_args, **kwargs)
#     446       else:
#     447         result = converted_f(*effective_args)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tf_quant_finance\models\euler_sampling.py in tf__sample(dim, drift_fn, volatility_fn, times, time_step, num_time_steps, num_samples, initial_state, random_type, seed, swap_memory, skip, precompute_normal_draws, times_grid, normal_draws, watch_params, validate_args, tolerance, dtype, name)
#     149                         ag__.if_stmt(ag__.ld(validate_args), if_body_7, else_body_7, get_state_7, set_state_7, (), 0)
#     150                     ag__.if_stmt((ag__.ld(times_grid) is None), if_body_8, else_body_8, get_state_8, set_state_8, ('num_time_steps', 'time_step', 'times_grid'), 3)
# --> 151                     (times, keep_mask, time_indices) = ag__.converted_call(ag__.ld(utils).prepare_grid, (), dict(times=ag__.ld(times), time_step=ag__.ld(time_step), num_time_steps=ag__.ld(num_time_steps), times_grid=ag__.ld(times_grid), tolerance=ag__.ld(tolerance), dtype=ag__.ld(dtype)), fscope)
#     152
#     153                     def get_state_11():
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443     try:
#     444       if kwargs is not None:
# --> 445         result = converted_f(*effective_args, **kwargs)
#     446       else:
#     447         result = converted_f(*effective_args)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tf_quant_finance\models\utils.py in tf__prepare_grid(times, time_step, dtype, tolerance, num_time_steps, times_grid)
#      66                 times_diff_1 = ag__.Undefined('times_diff_1')
#      67                 time_indices = ag__.Undefined('time_indices')
# ---> 68                 ag__.if_stmt((ag__.ld(times_grid) is None), if_body_2, else_body_2, get_state_2, set_state_2, ('all_times', 'time_indices'), 2)
#      69                 mask = ag__.converted_call(ag__.ld(tf).scatter_nd, (), dict(indices=ag__.converted_call(ag__.ld(tf).expand_dims, (ag__.converted_call(ag__.ld(tf).cast, (ag__.ld(time_indices),), dict(dtype=ag__.ld(tf).int64), fscope),), dict(axis=1), fscope), updates=ag__.converted_call(ag__.ld(tf).fill, (ag__.converted_call(ag__.ld(tf).shape, (ag__.ld(times),), None, fscope), 1), None, fscope), shape=ag__.converted_call(ag__.ld(tf).shape, (ag__.ld(all_times),), dict(out_type=ag__.ld(tf).int64), fscope)), fscope)
#      70                 mask = ag__.converted_call(ag__.ld(tf).where, ((ag__.ld(mask) > 0), True, False), None, fscope)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1322     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1323   else:
# -> 1324     _py_if_stmt(cond, body, orelse)
#    1325
#    1326
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in _py_if_stmt(cond, body, orelse)
#    1375 def _py_if_stmt(cond, body, orelse):
#    1376   """Overload of if_stmt that executes a Python if statement."""
# -> 1377   return body() if cond else orelse()
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tf_quant_finance\models\utils.py in if_body_2()
#      53                     all_times = ag__.Undefined('all_times')
#      54                     time_indices = ag__.Undefined('time_indices')
# ---> 55                     ag__.if_stmt((ag__.ld(num_time_steps) is None), if_body_1, else_body_1, get_state_1, set_state_1, ('all_times', 'time_indices'), 2)
#      56
#      57                 def else_body_2():
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1322     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1323   else:
# -> 1324     _py_if_stmt(cond, body, orelse)
#    1325
#    1326
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py in _py_if_stmt(cond, body, orelse)
#    1375 def _py_if_stmt(cond, body, orelse):
#    1376   """Overload of if_stmt that executes a Python if statement."""
# -> 1377   return body() if cond else orelse()
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tf_quant_finance\models\utils.py in if_body_1()
#      46                     def if_body_1():
#      47                         nonlocal all_times, time_indices
# ---> 48                         (all_times, time_indices) = ag__.converted_call(ag__.ld(_grid_from_time_step), (), dict(times=ag__.ld(times), time_step=ag__.ld(time_step), dtype=ag__.ld(dtype), tolerance=ag__.ld(tolerance)), fscope)
#      49
#      50                     def else_body_1():
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     443     try:
#     444       if kwargs is not None:
# --> 445         result = converted_f(*effective_args, **kwargs)
#     446       else:
#     447         result = converted_f(*effective_args)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tf_quant_finance\models\utils.py in tf___grid_from_time_step(times, time_step, dtype, tolerance)
#      16                 duplicate_mask = ag__.converted_call(ag__.ld(tf).math.greater, (ag__.ld(dt), ag__.ld(tolerance)), None, fscope)
#      17                 all_times = ag__.converted_call(ag__.ld(tf).boolean_mask, (ag__.ld(all_times), ag__.ld(duplicate_mask)), None, fscope)
# ---> 18                 time_indices = ag__.converted_call(ag__.ld(tf).searchsorted, (ag__.ld(all_times), ag__.ld(times)), dict(out_type=ag__.ld(tf).int32), fscope)
#      19                 time_indices = ag__.converted_call(ag__.ld(tf).math.minimum, (ag__.ld(time_indices), (ag__.converted_call(ag__.ld(tf).shape, (ag__.ld(all_times),), None, fscope)[0] - 1)), None, fscope)
#      20                 time_indices = ag__.converted_call(ag__.ld(tf).where, (((ag__.converted_call(ag__.ld(tf).gather, (ag__.ld(all_times), ag__.ld(time_indices)), None, fscope) - ag__.ld(times)) > ag__.ld(tolerance)), (ag__.ld(time_indices) - 1), ag__.ld(time_indices)), None, fscope)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     335   if conversion.is_in_allowlist_cache(f, options):
#     336     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 337     return _call_unconverted(f, args, kwargs, options, False)
#     338
#     339   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462
#     463   if kwargs is not None:
# --> 464     return f(*args, **kwargs)
#     465   return f(*args)
#     466
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\ops\array_ops.py in searchsorted(sorted_sequence, values, side, out_type, name)
#    6186   values_size = shape_internal(values)[-1]
#    6187   sorted_sequence_2d = reshape(sorted_sequence, [-1, sequence_size])
# -> 6188   values_2d = reshape(values, [-1, values_size])
#    6189   if side == "right":
#    6190     output = gen_array_ops.upper_bound(sorted_sequence_2d, values_2d, out_type,
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\ops\array_ops.py in reshape(tensor, shape, name)
#     195     A `Tensor`. Has the same type as `tensor`.
#     196   """
# --> 197   result = gen_array_ops.reshape(tensor, shape, name)
#     198   tensor_util.maybe_set_static_shape(result, shape)
#     199   return result
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in reshape(tensor, shape, name)
#    8544   # Add nodes to the TensorFlow graph.
#    8545   _, _, _op, _outputs = _op_def_library._apply_op_helper(
# -> 8546         "Reshape", tensor=tensor, shape=shape, name=name)
#    8547   _result = _outputs[:]
#    8548   if _execute.must_record_gradient():
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     491             try:
#     492               inferred = ops.convert_to_tensor(
# --> 493                   values, name=input_arg.name, as_ref=input_arg.is_ref)
#     494             except TypeError as err:
#     495               # When converting a python object such as a list of Dimensions, we
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1619
#    1620     if ret is None:
# -> 1621       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1622
#    1623     if ret is NotImplemented:
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1535   elif dtype != inferred_dtype:
#    1536     v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1537   return _autopacking_helper(v, dtype, name or "packed")
#    1538
#    1539
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\ops\array_ops.py in _autopacking_helper(list_or_tuple, dtype, name)
#    1470           # convertible-to-tensor types, such as numpy arrays.
#    1471           elems_as_tensors.append(
# -> 1472               constant_op.constant(elem, dtype=dtype, name=str(i)))
#    1473       return gen_array_ops.pack(elems_as_tensors, name=scope)
#    1474     else:
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     270   """
#     271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 272                         allow_broadcast=True)
#     273
#     274
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     292   attrs = {"value": tensor_value, "dtype": dtype_value}
#     293   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
# --> 294       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     295
#     296   if op_callbacks.should_invoke_op_callbacks():
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     689     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     690         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 691         compute_device)
#     692
#     693   def capture(self, tensor, name=None, shape=None):
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3703           input_types=input_types,
#    3704           original_op=self._default_original_op,
# -> 3705           op_def=op_def)
#    3706       self._create_op_helper(ret, compute_device=compute_device)
#    3707     return ret
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2096         op_def = self._graph._get_op_def(node_def.op)
#    2097       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2098                                 control_input_ops, op_def)
#    2099       name = compat.as_str(node_def.name)
#    2100
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\Dev\github\tf-quant-finance\venv\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1909   op_desc = pywrap_tf_session.TF_NewOperation(graph._c_graph,
#    1910                                               compat.as_str(node_def.op),
# -> 1911                                               compat.as_str(node_def.name))
#    1912   if node_def.device:
#    1913     pywrap_tf_session.TF_SetDevice(op_desc, compat.as_str(node_def.device))
#
# KeyboardInterrupt:
